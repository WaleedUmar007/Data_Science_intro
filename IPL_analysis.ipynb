# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import plotly.express as px

# %%
df= pd.read_csv("C:\\Users\\Dell\\Desktop\\AI Python Codes\\Datascience\\IPL Matches.csv", index_col="city")
df.head()
# Out:
#                 id       date player_of_match  \
# city
# Bangalore   335982  4/18/2008     BB McCullum
# Chandigarh  335983  4/19/2008      MEK Hussey
# Delhi       335984  4/19/2008     MF Maharoof
# Mumbai      335985  4/20/2008      MV Boucher
# Kolkata     335986  4/20/2008       DJ Hussey
#
#                                                  venue  neutral_venue  \
# city
# Bangalore                        M Chinnaswamy Stadium              0
# Chandigarh  Punjab Cricket Association Stadium, Mohali              0
# Delhi                                 Feroz Shah Kotla              0
# Mumbai                                Wankhede Stadium              0
# Kolkata                                   Eden Gardens              0
#
#                                   team1                        team2  \
# city
# Bangalore   Royal Challengers Bangalore        Kolkata Knight Riders
# Chandigarh              Kings XI Punjab          Chennai Super Kings
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, Bangalore to Dubai
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   date             816 non-null    object
#  2   player_of_match  812 non-null    object
#  3   venue            816 non-null    object
#  4   neutral_venue    816 non-null    int64
#  5   team1            816 non-null    object
#  6   team2            816 non-null    object
#  7   toss_winner      816 non-null    object
#  8   toss_decision    816 non-null    object
#  9   winner           812 non-null    object
#  10  result           812 non-null    object
#  11  result_margin    799 non-null    float64
#  12  eliminator       812 non-null    object
#  13  method           19 non-null     object
#  14  umpire1          816 non-null    object
#  15  umpire2          816 non-null    object
# ...

# %%
df.tail()
# Out:
#                 id        date player_of_match  \
# city
# Dubai      1216547   9/28/2020  AB de Villiers
# Dubai      1237177   11/5/2020       JJ Bumrah
# Abu Dhabi  1237178   11/6/2020   KS Williamson
# Abu Dhabi  1237180   11/8/2020      MP Stoinis
# Dubai      1237181  11/10/2020        TA Boult
#
#                                          venue  neutral_venue  \
# city
# Dubai      Dubai International Cricket Stadium              0
# Dubai      Dubai International Cricket Stadium              0
# Abu Dhabi                 Sheikh Zayed Stadium              0
# Abu Dhabi                 Sheikh Zayed Stadium              0
# Dubai      Dubai International Cricket Stadium              0
#
#                                  team1                team2  \
# city
# Dubai      Royal Challengers Bangalore       Mumbai Indians
# Dubai                   Mumbai Indians       Delhi Capitals
# Abu Dhabi  Royal Challengers Bangalore  Sunrisers Hyderabad
# ...

# %%
df.shape
# Out:
# (816, 16)

# %%
df.isnull().sum()
# Out:
# id                   0
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
result_method="regular match"
df.fillna(result_method,inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# eliminator         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'date', 'player_of_match', 'venue', 'neutral_venue', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
x=df.venue
y=df.toss_decision
plt.barh(x,y,color)
# Out:
# <BarContainer object of 816 artists>
